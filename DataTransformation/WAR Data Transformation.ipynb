# %% [markdown]
# # WAR Data Transformation
#
# Task: use Pandas to transform csv files into DataFrames that match desired tables for database schema
#
# Tables:
#
# - WAR
# - WAR_PARTICIPANTS
# - WAR_LOCATIONS
# - WAR_TRANSITIONS

# %% [markdown]
# ![](../DatabaseDesign/IRDB_WAR_Tables.png)

# %%
import pandas as pd
import numpy as np

# %%
dfInterStateWar = pd.read_csv("../SourceData/CorrelatesOfWar/Inter-StateWarData_v4.0.csv", encoding='utf-8', na_values=[-7, -8, -9])
dfIntraStateWar = pd.read_csv("../SourceData/CorrelatesOfWar/Intra-StateWarData_v4.1.csv", encoding='latin-1', na_values=[-7, -8, -9])
dfExtraStateWar = pd.read_csv("../SourceData/CorrelatesOfWar/Extra-StateWarData_v4.0.csv", encoding='latin-1', na_values=[-7, -8, -9])
dfNonStateWar = pd.read_csv("../SourceData/CorrelatesOfWar/Non-StateWarData_v4.0.csv", encoding='utf-8', na_values=[-7, -8, -9])

dfPolities = pd.read_csv("../FinalData/polity.csv", encoding='utf-8')
dfWarNames = pd.read_csv("../SourceData/CorrelatesOfWar/CowWarList.csv", encoding='utf-8')

# %% [markdown]
# ## Create 'WAR' table
#
# Task: transform the following csv files into one table:
#
# - Inter-StateWarData_v4.0.csv (note: already saved as 'dfInterStateWar')
# - Intra-StateWarData_v4.1.csv (note: already saved as 'dfIntraStateWar')
# - Non-StateWarData_v4.0.csv (note: already saved as 'dfNonStateWar')
# - Extra-StateWarData_v4.0.csv (note: already saved as 'dfExtraStateWar')
# - CowWarList.csv (note: generated from pdf using Tabula, with `\r`s removed by hand)
#
# with the following attributes:
#
# - WarID
# - WarShortName
# - WarLongName (from CowWarList.csv)
# - WarType
# - IsIntervention (only relevant for Extra-State Wars)
# - IsInternational (only relevant for Intra-State Wars)
#
# Note: The carriage return characters (in CowWarList.csv) can also be removed with this code:
#
# `df = df.replace({r'\r': ' '}, regex=True)`

# %%
dfInterWar = dfInterStateWar[['WarNum', 'WarName', 'WarType']]
dfInterWar = dfInterWar.rename(columns={'WarNum':'WarID', 'WarName':'WarShortName'})
dfInterWar = dfInterWar.drop_duplicates()

dfIntraWar = dfIntraStateWar[['WarNum', 'WarName', 'WarType', 'Intnl']]
dfIntraWar = dfIntraWar.rename(columns={'WarNum':'WarID', 'WarName':'WarShortName', 'Intnl':'IsInternational'})
dfIntraWar = dfIntraWar.drop_duplicates()

dfNonWar = dfNonStateWar[['WarNum', 'WarName', 'WarType']]
dfNonWar = dfNonWar.rename(columns={'WarNum':'WarID', 'WarName':'WarShortName'})
dfNonWar = dfNonWar.drop_duplicates()

dfExtraWar = dfExtraStateWar[['WarNum', 'WarName', 'WarType', 'Interven']]
dfExtraWar = dfExtraWar.rename(columns={'WarNum':'WarID', 'WarName':'WarShortName', 'Interven':'IsIntervention'})
dfExtraWar = dfExtraWar.drop_duplicates()

warDFs = [dfInterWar, dfIntraWar, dfNonWar, dfExtraWar]
dfWar = pd.concat(warDFs, sort=True).sort_values('WarID').reset_index(drop=True)
dfWar = dfWar[['WarID', 'WarShortName', 'WarType', 'IsIntervention', 'IsInternational']]
dfWar = dfWar.astype({'IsIntervention':'Int64', 'IsInternational':'Int64'})

# %% [markdown]
# Now to add the long names and the general category war type:

# %%
dfWarNamesIDs = dfWarNames['War Type & Number'].str.split("#", n = 1, expand = True)
dfWarNames['WarTypeName'] = dfWarNamesIDs[0]
dfWarNames['WarID'] = dfWarNamesIDs[1]

dfWarNames = dfWarNames[['WarID', 'WarTypeName', 'War Name']]
dfWarNames = dfWarNames.rename(columns={'War Name':'WarLongName'})
dfWarNames = dfWarNames.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
dfWarNames['WarID'] = dfWarNames['WarID'].astype(int)

# %%
dfWars = pd.merge(dfWar, dfWarNames, on='WarID')
dfWars = dfWars[['WarID', 'WarShortName', 'WarLongName', 'WarType', 'WarTypeName', 'IsIntervention', 'IsInternational']]
dfWars
# Out:
#      WarID               WarShortName  \
# 0        1         Franco-Spanish War
# 1        4        First Russo-Turkish
# 2        7           Mexican-American
# 3       10           Austro-Sardinian
# 4       13   First Schleswig-Holstein
# ..     ...                        ...
# 649   1574  Rwandan Social Revolution
# 650   1577   Dhofar Rebellion Phase 1
# 651   1581        Angola Guerilla War
# 652   1582  East Timorese War Phase 1
# 653   1594            Hemda-Lendu War
#
#                                    WarLongName  WarType      WarTypeName  \
# 0                   Franco-Spanish War of 1823        1  Inter-State War
# 1         First Russo-Turkish War of 1828-1829        1  Inter-State War
# 2            Mexican-American War of 1846-1847        1  Inter-State War
# 3            Austro-Sardinian War of 1848-1849        1  Inter-State War
# 4    First Schleswig-Holstein War of 1848-1849        1  Inter-State War
# ..                                         ...      ...              ...
# 649     Rwandan Social Revolution of 1959-1962        8    Non-State War
# 650      Dhofar Rebellion Phase 1 of 1968-1971        8    Non-State War
# 651           Angola Guerilla War of 1974-1975        8    Non-State War
# 652          East Timorese War Phase 1 of 1975        8    Non-State War
# 653                Hema-Lendu War of 1999-2005        9    Non-State War
#
#      IsIntervention  IsInternational
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# ..              ...              ...
# 649             NaN              NaN
# 650             NaN              NaN
# 651             NaN              NaN
# 652             NaN              NaN
# 653             NaN              NaN
#
# [654 rows x 7 columns]

# %%
dfWars.to_csv('../FinalData/war.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Create 'WAR_PARTICIPANTS' table
#
# Task: transform the following csv files into one table:
#
# - Inter-StateWarData_v4.0.csv (note: already saved as 'dfInterStateWar')
# - Intra-StateWarData_v4.1.csv (note: already saved as 'dfIntraStateWar')
# - Non-StateWarData_v4.0.csv (note: already saved as 'dfNonStateWar')
# - Extra-StateWarData_v4.0.csv (note: already saved as 'dfExtraStateWar')
#
# with the following attributes:
#
# - WarID
# - PolityID
# - StartDate
# - EndDate
# - StartYear
# - StartMonth
# - StartDay
# - EndYear
# - EndMonth
# - EndDay
# - Side
# - IsInitiator
# - Outcome
# - Deaths
#
# Note: 'Outcome' is pretty much entirely determined by 'WarID' and 'Side'. However, one codebook (interstate war) has an additional outcome type: 8 = changed sides. There is exactly 1 instance of this. Therefore, 'Outcome' must also be determined by 'PolityID'. This is why it is included in this table, and not a seperate one.
#
# Similarly, 'Deaths' is almost entirely deterimined by 'WarID' and 'PolityID'. However, there are a very few instances in which it is also dependent on 'StartDate', which is why it is included in this table, and not a seperate one.

# %% [markdown]
# ### Inter-State War

# %%
dfInterStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'ccode', 'StateName', 'Side',
#        'StartMonth1', 'StartDay1', 'StartYear1', 'EndMonth1', 'EndDay1',
#        'EndYear1', 'StartMonth2', 'StartDay2', 'StartYear2', 'EndMonth2',
#        'EndDay2', 'EndYear2', 'TransFrom', 'WhereFought', 'Initiator',
#        'Outcome', 'TransTo', 'BatDeath', 'Version'],
#       dtype='object')

# %%
dfInterWarPar1 = dfInterStateWar[['WarNum', 'ccode', 'StartMonth1', 'StartDay1', 'StartYear1', 
                                  'EndMonth1', 'EndDay1', 'EndYear1', 'Side', 'Initiator', 'Outcome', 
                                  'BatDeath']] \
                                .rename(columns= {'WarNum':'WarID', 'ccode':'PolityID', 'StartMonth1':'StartMonth', 
                                        'StartDay1':'StartDay', 'StartYear1':'StartYear', 'EndMonth1':'EndMonth', 
                                        'EndDay1':'EndDay', 'EndYear1':'EndYear', 'Initiator':'IsInitiator', 
                                        'BatDeath':'Deaths'})

dfInterWarPar2 = dfInterStateWar[['WarNum', 'ccode', 'StartMonth2', 'StartDay2', 'StartYear2', 
                                  'EndMonth2', 'EndDay2', 'EndYear2', 'Side', 'Initiator', 'Outcome', 
                                  'BatDeath']] \
                                .rename(columns={'WarNum':'WarID', 'ccode':'PolityID', 'StartMonth2':'StartMonth', 
                                        'StartDay2':'StartDay', 'StartYear2':'StartYear', 'EndMonth2':'EndMonth', 
                                        'EndDay2':'EndDay', 'EndYear2':'EndYear', 'Initiator':'IsInitiator', 
                                        'BatDeath':'Deaths'}) \
                                .dropna(subset=['StartMonth', 'StartDay', 'StartYear'], how='all')

# %% [markdown]
# according to codebook, for the 'Initiator' column, 1 = yes, did initiate; 2 = no, did not initiate. Need to standardize by changing the 2 to 0 (the more universally recognized number for False)
#
# original table as possible values in 'Side' column as 1 and 2. In order to standardize with other tables, need to convert these to A and B.

# %%
dfInterWarPar = pd.concat([dfInterWarPar1, dfInterWarPar2]) \
                .reset_index(drop=True) \
                .replace({'IsInitiator': {2: 0}, 'Side': {1: 'A', 2: 'B'}})

dfInterWarPar = dfInterWarPar[['WarID', 'PolityID', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Side', 'IsInitiator', 'Outcome', 'Deaths']]
dfInterWarPar
# Out:
#      WarID  PolityID  StartYear  StartMonth  StartDay  EndYear  EndMonth  \
# 0        1       230     1823.0         4.0       7.0   1823.0      11.0
# 1        1       220     1823.0         4.0       7.0   1823.0      11.0
# 2        4       640     1828.0         4.0      26.0   1829.0       9.0
# 3        4       365     1828.0         4.0      26.0   1829.0       9.0
# 4        7        70     1846.0         4.0      25.0   1847.0       9.0
# ..     ...       ...        ...         ...       ...      ...       ...
# 351    148       660     1948.0        10.0      15.0   1948.0      10.0
# 352    148       663     1948.0        10.0      15.0   1948.0      10.0
# 353    148       645     1948.0        10.0      15.0   1948.0      10.0
# 354    184       640     1974.0         8.0      14.0   1974.0       8.0
# 355    184       352     1974.0         8.0      14.0   1974.0       8.0
#
#      EndDay Side  IsInitiator  Outcome   Deaths
# 0      13.0    B            0        2    600.0
# 1      13.0    A            1        1    400.0
# 2      14.0    B            0        2  80000.0
# 3      14.0    A            1        1  50000.0
# 4      14.0    B            0        2   6000.0
# ..      ...  ...          ...      ...      ...
# 351    31.0    B            0        2    500.0
# 352    31.0    B            1        2   1000.0
# 353    31.0    B            0        2    500.0
# 354    16.0    A            1        1   1000.0
# 355    16.0    B            0        2    500.0
#
# [356 rows x 12 columns]

# %% [markdown]
# ### Intra-State War

# %%
dfIntraStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'CcodeA', 'SideA', 'CcodeB', 'SideB',
#        'Intnl', 'StartMonth1', 'StartDay1', 'StartYear1', 'EndMonth1',
#        'EndDay1', 'EndYear1', 'StartMonth2', 'StartDay2', 'StartYear2',
#        'EndMonth2', 'EndDay2', 'EndYear2', 'TransFrom', 'WhereFought',
#        'Initiator', 'Outcome', 'TransTo', 'SideADeaths', 'SideBDeaths',
#        'Version'],
#       dtype='object')

# %% [markdown]
# - 1A = Side A, First set of start/end dates
# - 2A = Side A, Second set of start/end dates (need to get rid of rows with no date values)
# - 1B = Side B, First set of start/end dates
# - 2B = Side B, Second set of start/end dates (need to get rid of rows with no date values)

# %%
dfIntraWarPar1A = dfIntraStateWar[['WarNum', 'CcodeA', 'SideA', 'StartMonth1', 'StartDay1', 'StartYear1', 
                                   'EndMonth1', 'EndDay1', 'EndYear1', 'Initiator', 'Outcome', 'SideADeaths']] \
                                 .rename(columns={'WarNum':'WarID', 'CcodeA':'PolityID', 'SideA':'PolityName', 
                                                  'StartMonth1':'StartMonth', 'StartDay1':'StartDay', 
                                                  'StartYear1':'StartYear', 'EndMonth1':'EndMonth', 
                                                  'EndDay1':'EndDay', 'EndYear1':'EndYear', 'SideADeaths':'Deaths'})

dfIntraWarPar2A = dfIntraStateWar[['WarNum', 'CcodeA', 'SideA', 'StartMonth2', 'StartDay2', 'StartYear2', 
                                   'EndMonth2', 'EndDay2', 'EndYear2', 'Initiator', 'Outcome', 'SideADeaths']] \
                                 .rename(columns={'WarNum':'WarID', 'CcodeA':'PolityID', 'SideA':'PolityName', 
                                                  'StartMonth2':'StartMonth', 'StartDay2':'StartDay', 
                                                  'StartYear2':'StartYear', 'EndMonth2':'EndMonth', 
                                                  'EndDay2':'EndDay', 'EndYear2':'EndYear', 'SideADeaths':'Deaths'}) \
                                 .dropna(subset=['StartMonth', 'StartDay', 'StartYear'], how='all')

dfIntraWarPar1B = dfIntraStateWar[['WarNum', 'CcodeB', 'SideB', 'StartMonth1', 'StartDay1', 'StartYear1', 
                                   'EndMonth1', 'EndDay1', 'EndYear1', 'Initiator', 'Outcome', 'SideBDeaths']] \
                                 .rename(columns={'WarNum':'WarID', 'CcodeB':'PolityID', 'SideB':'PolityName', 
                                                  'StartMonth1':'StartMonth', 'StartDay1':'StartDay', 
                                                  'StartYear1':'StartYear', 'EndMonth1':'EndMonth', 
                                                  'EndDay1':'EndDay', 'EndYear1':'EndYear', 'SideBDeaths':'Deaths'})

dfIntraWarPar2B = dfIntraStateWar[['WarNum', 'CcodeB', 'SideB', 'StartMonth2', 'StartDay2', 'StartYear2', 
                                   'EndMonth2', 'EndDay2', 'EndYear2', 'Initiator', 'Outcome', 'SideBDeaths']] \
                                 .rename(columns={'WarNum':'WarID', 'CcodeB':'PolityID', 'SideB':'PolityName', 
                                                  'StartMonth2':'StartMonth', 'StartDay2':'StartDay', 
                                                  'StartYear2':'StartYear', 'EndMonth2':'EndMonth', 
                                                  'EndDay2':'EndDay', 'EndYear2':'EndYear', 'SideBDeaths':'Deaths'}) \
                                 .dropna(subset=['StartMonth', 'StartDay', 'StartYear'], how='all')

# %% [markdown]
# for side B, the outcomes needs to be switched in order to reflect the schema of 1 = this side won, and 2 = this side lost

# %%
dfIntraWarParA = pd.concat([dfIntraWarPar1A, dfIntraWarPar2A]) \
                   .reset_index(drop=True) \
                   .dropna(subset=['PolityName'])
dfIntraWarParA['Side'] = 'A'

dfIntraWarParB = pd.concat([dfIntraWarPar1B, dfIntraWarPar2B]) \
                   .reset_index(drop=True) \
                   .dropna(subset=['PolityName'])
dfIntraWarParB['Side'] = 'B'

dfIntraWarParB = dfIntraWarParB.replace({'Outcome': {2: 20, 1: 10}}) \
                               .replace({'Outcome': {20: 1, 10: 2}})

# %%
dfIntraWarPar = pd.concat([dfIntraWarParA, dfIntraWarParB]) \
                .sort_values('WarID') \
                .reset_index(drop=True)

dfIntraWarPar['PolityName'] = dfIntraWarPar['PolityName'].str.strip()
dfIntraWarPar['Initiator'] = dfIntraWarPar['Initiator'].str.strip()

# %% [markdown]
# create the 'IsInitiator' column based on the 'Initiator' column.
#
# Intra-State War is the only table that records the initiator as a text value. If it matches the polity name, that is an easy fix. If it does not match the polity name, need to manually determine the correct initiator.

# %%
dfIntraWarPar['IsInitiator'] = 0
dfIntraWarPar.loc[dfIntraWarPar['PolityName'] == dfIntraWarPar['Initiator'], 'IsInitiator'] = 1

# %%
checkinit = dfIntraWarPar.groupby('WarID')['IsInitiator'].sum()
checkinit.value_counts()
# Out:
# 1    276
# 0     51
# 2      7
# Name: IsInitiator, dtype: int64

# %% [markdown]
# 276 wars are ok - there is one initiator (what it should be). 51 wars are missing an initiator - need to manually go through these. 7 wars have two initiators - need to double check what is going on here.

# %%
doubleInit = checkinit.loc[checkinit==2].index
dfIntraWarPar[dfIntraWarPar.WarID.isin(doubleInit)]
# Out:
#      WarID  PolityID           PolityName  StartMonth  StartDay  StartYear  \
# 86     547       NaN             Liberals         5.0      15.0     1848.0
# 87     547       NaN             Liberals         1.0      12.0     1848.0
# 88     547     329.0         Two Sicilies         5.0      15.0     1848.0
# 89     547     329.0         Two Sicilies         1.0      12.0     1848.0
# 161    590       NaN        Conservatives         8.0      14.0     1869.0
# 162    590       NaN        Conservatives         1.0      11.0     1868.0
# 163    590     101.0            Venezuela         1.0      11.0     1868.0
# 164    590     101.0            Venezuela         8.0      14.0     1869.0
# 211    623       NaN      Tonghak Society         9.0      14.0     1894.0
# 212    623       NaN      Tonghak Society         2.0      29.0     1894.0
# 213    623     730.0                Korea         9.0      14.0     1894.0
# 214    623     730.0                Korea         2.0      29.0     1894.0
# 215    623     740.0                Japan        10.0      24.0     1894.0
# 360    720     200.0       United Kingdom        12.0       5.0     1944.0
# 361    720     350.0               Greece        12.0       3.0     1944.0
# 362    720       NaN           Communists        12.0       3.0     1944.0
# 363    720     350.0               Greece         2.0      12.0     1946.0
# 364    720       NaN           Communists         2.0      12.0     1946.0
# 587    836     625.0                Sudan        11.0      17.0     1983.0
# 588    836       NaN  SPLA-Garang faction         4.0      15.0     1992.0
# 589    836     625.0                Sudan         4.0      15.0     1992.0
# 590    836       NaN  SPLA-Garang faction        11.0      17.0     1983.0
# 664    877     344.0              Croatia         3.0      20.0     1995.0
# 665    877       NaN        Bosnian Serbs         3.0      20.0     1995.0
# 666    877     346.0               Bosnia         6.0       6.0     1992.0
# 667    877     344.0              Croatia        10.0      19.0     1992.0
# 668    877       2.0        United States         8.0      30.0     1995.0
# 669    877     346.0               Bosnia         3.0      20.0     1995.0
# 670    877     344.0              Croatia         2.0      23.0     1994.0
# 671    877       NaN        Bosnian Serbs         6.0       6.0     1992.0
# 707    898     200.0       United Kingdom         5.0       8.0     2000.0
# 708    898     438.0               Guinea         2.0       6.0     1998.0
# 709    898     475.0              Nigeria         2.0       6.0     1998.0
# 710    898     452.0                Ghana         2.0       6.0     1998.0
# 711    898       NaN       Kabbah faction         2.0       6.0     1998.0
# 712    898     452.0                Ghana         5.0      11.0     2000.0
# 713    898       NaN       Kabbah faction         5.0      11.0     2000.0
# 714    898     438.0               Guinea         5.0      11.0     2000.0
# 715    898     451.0         Sierra Leone         2.0       6.0     1998.0
# 716    898     475.0              Nigeria         5.0      11.0     2000.0
# 717    898     451.0         Sierra Leone         5.0      11.0     2000.0
#
#      EndMonth  EndDay  EndYear            Initiator  Outcome Deaths Side  \
# 86        5.0    15.0   1849.0             Liberals        2    NaN    B
# 87        1.0    27.0   1848.0             Liberals        2    NaN    B
# 88        5.0    15.0   1849.0             Liberals        1   1500    A
# 89        1.0    27.0   1848.0             Liberals        1   1500    A
# 161       1.0     7.0   1871.0        Conservatives        1    NaN    B
# 162       8.0    14.0   1868.0        Conservatives        1    NaN    B
# 163       8.0    14.0   1868.0        Conservatives        2    NaN    A
# 164       1.0     7.0   1871.0        Conservatives        2    NaN    A
# 211      11.0    28.0   1894.0      Tonghak Society        2    NaN    B
# 212       5.0     6.0   1894.0      Tonghak Society        2    NaN    B
# 213      11.0    28.0   1894.0      Tonghak Society        1    NaN    A
# 214       5.0     6.0   1894.0      Tonghak Society        1    NaN    A
# 215      11.0    28.0   1894.0      Tonghak Society        1    NaN    A
# 360       1.0    11.0   1945.0           Communists        1    237    A
# 361       2.0    12.0   1945.0           Communists        1  17970    A
# 362       2.0    12.0   1945.0           Communists        2  50000    B
# 363      10.0    16.0   1949.0           Communists        1  17970    A
# 364      10.0    16.0   1949.0           Communists        2  50000    B
# 587       8.0    27.0   1991.0  SPLA-Garang faction        3    NaN    A
# 588       1.0    10.0   2005.0  SPLA-Garang faction        3    NaN    B
# 589       1.0    10.0   2005.0  SPLA-Garang faction        3    NaN    A
# 590       8.0    27.0   1991.0  SPLA-Garang faction        3    NaN    B
# 664      12.0    14.0   1995.0        Bosnian Serbs        2    185    B
# 665      12.0    14.0   1995.0        Bosnian Serbs        2  18543    B
# 666      12.0    31.0   1994.0        Bosnian Serbs        1  27500    A
# 667       2.0    22.0   1994.0        Bosnian Serbs        1    NaN    A
# 668       9.0    20.0   1995.0        Bosnian Serbs        1      0    A
# 669      12.0    14.0   1995.0        Bosnian Serbs        1  27500    A
# 670      12.0    31.0   1994.0        Bosnian Serbs        2    185    B
# 671      12.0    31.0   1994.0        Bosnian Serbs        2  18543    B
# 707      11.0    10.0   2000.0       Kabbah faction        1    NaN    B
# 708       7.0     7.0   1999.0       Kabbah faction        1    NaN    B
# 709       7.0     7.0   1999.0       Kabbah faction        1    NaN    B
# 710       7.0     7.0   1999.0       Kabbah faction        1    NaN    B
# 711       7.0     7.0   1999.0       Kabbah faction        1    NaN    B
# 712      11.0    10.0   2000.0       Kabbah faction        1    NaN    B
# 713      11.0    10.0   2000.0       Kabbah faction        1    NaN    B
# 714      11.0    10.0   2000.0       Kabbah faction        1    NaN    B
# 715       7.0     7.0   1999.0       Kabbah faction        2    NaN    A
# 716      11.0    10.0   2000.0       Kabbah faction        1    NaN    B
# 717      11.0    10.0   2000.0       Kabbah faction        2    NaN    A
#
#      IsInitiator
# 86             1
# 87             1
# 88             0
# 89             0
# 161            1
# 162            1
# 163            0
# 164            0
# 211            1
# 212            1
# 213            0
# 214            0
# 215            0
# 360            0
# 361            0
# 362            1
# 363            0
# 364            1
# 587            0
# 588            1
# 589            0
# 590            1
# 664            0
# 665            1
# 666            0
# 667            0
# 668            0
# 669            0
# 670            0
# 671            1
# 707            0
# 708            0
# 709            0
# 710            0
# 711            1
# 712            0
# 713            1
# 714            0
# 715            0
# 716            0
# 717            0

# %% [markdown]
# looks like the double init cases are just when an initiating party left the conflict and re-entered at a later date - this is fine.

# %%
missingInit = checkinit.loc[checkinit==0].index

with pd.option_context("display.max_rows", 120):
    display(dfIntraWarPar[dfIntraWarPar.WarID.isin(missingInit)])
# Out:
#      WarID  PolityID                                       PolityName  \
# 0      500     365.0                                           Russia
# 1      500       NaN                 Georgians, Dhagestania, Chechens
# 36     518     640.0                                   Ottoman Empire
# 37     518       NaN                               Egyptians & Bashir
# 63     533     640.0                                   Ottoman Empire
# 64     533       NaN                                            Egypt
# 78     542     640.0                                   Ottoman Empire
# 79     542       NaN                                          Karbala
# 90     548       NaN                           Paez led Conservatives
# 91     548     101.0                                        Venezuela
# 100    554     300.0                                          Austria
# 101    554     365.0                                           Russia
# 102    554       NaN                                          Hungary
# 105    556     640.0                                   Ottoman Empire
# 106    556       NaN                         Montenegro & Hercegovina
# 109    558      70.0                                           Mexico
# 110    558       NaN                                           Puebla
# 130    571     710.0                                            China
# 131    571       NaN                                    Muslims (Hui)
# 136    575       NaN                                       Montenegro
# 137    575     640.0                                           Turkey
# 142    578     145.0                                           Boliva
# 143    578       NaN                       Gregorio Perez's followers
# 153    585       NaN                        Zhang Jizhong's followers
# 154    585     710.0                                            China
# 155    586       NaN                                       Montoneros
# 156    586     160.0                                        Argentina
# 242    642     640.0                                   Ottoman Empire
# 243    642       NaN                              Imam Yahya's forces
# 258    651       NaN    Yemen & Asir Imam Ibn Idris & Sayyid Muhammad
# 259    651     640.0                                   Ottoman Empire
# 264    657     710.0                                            China
# 265    657       NaN                               Nat. Rel. Alliance
# 279    676     365.0                                           Russia
# 280    676       NaN                                 Kirghiz & Kazaks
# 288    680       NaN                                        Red Guard
# 289    680     375.0                                          Finland
# 290    680     365.0                                             USSR
# 291    680     255.0                                          Germany
# 292    681       NaN                                       Ukrainians
# 293    681       NaN                                    Ukraine Poles
# 298    685       NaN                                       Anhui army
# 299    685       NaN                                Chihli & Fengtien
# 309    691     365.0                                             USSR
# 310    691       NaN                             Basmachi/Enver Pasha
# 330    703       NaN                                    Gansu Muslims
# 331    703     710.0                                            China
# 336    707       NaN                               Escobar Led Rebels
# 337    707      70.0                                           Mexico
# 355    718     230.0                                            Spain
# 356    718     325.0                                            Italy
# 357    718     255.0                                          Germany
# 358    718     235.0                                         Portugal
# 359    718       NaN                                          Falange
# 394    740       NaN                                         Military
# 395    740     160.0                                        Argentina
# 400    743       2.0                         United States of America
# 401    743       NaN                                   National Front
# 402    743     660.0                                          Lebanon
# 460    773     775.0                                            Burma
# 461    773       NaN                              Karens & Communists
# 496    793     155.0                                            Chile
# 497    793       NaN                            Pinochet led military
# 526    806       NaN                                         Fretilin
# 527    806     850.0                                        Indonesia
# 528    807       NaN                                  Lebanese Forces
# 529    807       NaN                             PLO & Shiite militia
# 530    807     652.0                                            Syria
# 531    807     666.0                                           Israel
# 544    812       NaN                                       Mujahideen
# 545    812     700.0                                      Afghanistan
# 546    812     365.0                                           Russia
# 551    816     630.0                                             Iran
# 552    816       NaN  Anti-Khmoneini Coalition: Fedayeen Kalq & Kurds
# 572    827       NaN                              Shining Path & TARM
# 573    827     135.0                                             Peru
# 578    832       NaN                            Karen & Kachin Rebels
# 579    832     775.0                                            Burma
# 580    833     220.0                                           France
# 581    833     660.0                                          Lebanon
# 582    833       2.0                                    United States
# 583    833       NaN                                 Shi'ites & Druze
# 598    842     680.0                          Yemen People's Republic
# 599    842       NaN                                 Leftist Factions
# 608    848       NaN                                      rebel clans
# 609    848     520.0                                          Somalia
# 615    852       NaN                                       Deby's MPS
# 616    852     483.0                                             Chad
# 619    854     910.0                                 Papua New Guinea
# 620    854       NaN                                              BRA
# 621    856       NaN                                FARC & Drug Lords
# 622    856     100.0                                         Colombia
# 632    862     645.0                                             Iraq
# 633    862       NaN                                  Shiites & Kurds
# 636    864     345.0                                Yugoslavia/Serbia
# 637    864       NaN                                          Croatia
# 691    891     344.0                                          Croatia
# 692    891       NaN                                   Krajinia Serbs
# 693    892     450.0                                          Liberia
# 694    892       NaN                                             NPFL
# 697    895     500.0                                           Uganda
# 698    895       NaN                                             ADFL
# 699    895     517.0                                           Rwanda
# 700    895     490.0                                              DRC
# 701    895     540.0                                           Angola
# 748    915     365.0                                           Russia
# 749    915       NaN                                         Chechnya
# 750    916     840.0                                      Philippines
# 751    916       NaN                                             MILF
# 754    918     516.0                                          Burundi
# 755    918       NaN                                    FNL & FROLINA
# 756    920     517.0                                           Rwanda
# 757    920       NaN                Army for the Liberation of Rwanda
# 769    927     625.0                                            Sudan
# 770    927       NaN                                        SLA & JEM
# 775    932       NaN                                    Waziri tribes
# 776    932       2.0                                    United States
# 777    932     770.0                                         Pakistan
#
#      StartMonth  StartDay  StartYear  EndMonth   EndDay  EndYear  \
# 0           6.0      10.0     1818.0       NaN      NaN   1822.0
# 1           6.0      10.0     1818.0       NaN      NaN   1822.0
# 36         10.0       1.0     1831.0      12.0     27.0   1832.0
# 37         10.0       1.0     1831.0      12.0     27.0   1832.0
# 63          6.0      10.0     1839.0       6.0     24.0   1839.0
# 64          6.0      10.0     1839.0       6.0     24.0   1839.0
# 78         12.0      19.0     1842.0       1.0     13.0   1843.0
# 79         12.0      19.0     1842.0       1.0     13.0   1843.0
# 90          2.0       4.0     1848.0       8.0     15.0   1849.0
# 91          2.0       4.0     1848.0       8.0     15.0   1849.0
# 100         9.0       9.0     1848.0       8.0     13.0   1849.0
# 101         7.0      16.0     1849.0       8.0     13.0   1849.0
# 102         9.0       9.0     1848.0       8.0     13.0   1849.0
# 105        12.0       2.0     1852.0       3.0     13.0   1853.0
# 106        12.0       2.0     1852.0       3.0     13.0   1853.0
# 109        12.0      11.0     1855.0       3.0     21.0   1856.0
# 110        12.0      11.0     1855.0       3.0     21.0   1856.0
# 130        10.0      25.0     1860.0      12.0     26.0   1872.0
# 131        10.0      25.0     1860.0      12.0     26.0   1872.0
# 136        12.0       NaN     1861.0       8.0     31.0   1862.0
# 137        12.0       NaN     1861.0       8.0     31.0   1862.0
# 142         9.0      15.0     1862.0       9.0     15.0   1862.0
# 143         9.0      15.0     1862.0       9.0     15.0   1862.0
# 153        10.0       NaN     1866.0      10.0 -91866.0      NaN
# 154        10.0       NaN     1866.0      10.0 -91866.0      NaN
# 155        12.0      15.0     1866.0      10.0     15.0   1867.0
# 156        12.0      15.0     1866.0      10.0     15.0   1867.0
# 242        11.0       8.0     1904.0       1.0     10.0   1906.0
# 243        11.0       8.0     1904.0       1.0     10.0   1906.0
# 258        10.0      15.0     1910.0      10.0      9.0   1911.0
# 259        10.0      15.0     1910.0      10.0      9.0   1911.0
# 264        10.0      11.0     1911.0      12.0     31.0   1911.0
# 265        10.0      11.0     1911.0      12.0     31.0   1911.0
# 279         7.0       4.0     1916.0       2.0     27.0   1917.0
# 280         7.0       4.0     1916.0       2.0     27.0   1917.0
# 288         1.0      28.0     1918.0       4.0     30.0   1918.0
# 289         1.0      28.0     1918.0       4.0     30.0   1918.0
# 290         1.0      28.0     1918.0       5.0     16.0   1918.0
# 291         4.0       3.0     1918.0       5.0     16.0   1918.0
# 292        11.0       1.0     1918.0       2.0     13.0   1919.0
# 293        11.0       1.0     1918.0       2.0     13.0   1919.0
# 298         7.0      14.0     1920.0       7.0     19.0   1920.0
# 299         7.0      14.0     1920.0       7.0     19.0   1920.0
# 309        11.0      10.0     1921.0       7.0      NaN   1923.0
# 310        11.0      10.0     1921.0       7.0      NaN   1923.0
# 330         NaN       NaN     1928.0       NaN      NaN   1930.0
# 331         NaN       NaN     1928.0       NaN      NaN   1930.0
# 336         3.0       3.0     1929.0       5.0      4.0   1929.0
# 337         3.0       3.0     1929.0       5.0      4.0   1929.0
# 355         7.0      18.0     1936.0       3.0     29.0   1939.0
# 356         7.0      30.0     1936.0       3.0     29.0   1939.0
# 357         8.0      27.0     1936.0       3.0     29.0   1939.0
# 358         8.0       1.0     1936.0       3.0     29.0   1939.0
# 359         7.0      18.0     1936.0       3.0     29.0   1939.0
# 394         6.0      15.0     1955.0       9.0     19.0   1955.0
# 395         6.0      15.0     1955.0       9.0     19.0   1955.0
# 400         7.0      16.0     1958.0       9.0     15.0   1958.0
# 401         5.0       9.0     1958.0       9.0     15.0   1958.0
# 402         5.0       9.0     1958.0       9.0     15.0   1958.0
# 460         6.0       NaN     1967.0      10.0     22.0   1980.0
# 461         6.0       NaN     1967.0      10.0     22.0   1980.0
# 496         9.0      11.0     1973.0       9.0     15.0   1973.0
# 497         9.0      11.0     1973.0       9.0     15.0   1973.0
# 526         7.0      18.0     1976.0       5.0     26.0   1979.0
# 527         7.0      18.0     1976.0       5.0     26.0   1979.0
# 528         2.0       1.0     1978.0      10.0      4.0   1978.0
# 529         2.0       1.0     1978.0      10.0      4.0   1978.0
# 530         2.0       1.0     1978.0      10.0      4.0   1978.0
# 531         3.0      14.0     1978.0      10.0      4.0   1978.0
# 544         9.0       1.0     1978.0       2.0     21.0   1980.0
# 545         9.0       1.0     1978.0       2.0     21.0   1980.0
# 546         3.0      15.0     1979.0       2.0     21.0   1980.0
# 551         2.0      12.0     1979.0       3.0      NaN   1984.0
# 552         2.0      12.0     1979.0       3.0      NaN   1984.0
# 572         3.0       4.0     1982.0       9.0     12.0   1992.0
# 573         3.0       4.0     1982.0       9.0     12.0   1992.0
# 578         2.0       1.0     1983.0       1.0      NaN   1988.0
# 579         2.0       1.0     1983.0       1.0      NaN   1988.0
# 580         4.0      18.0     1983.0       2.0     29.0   1984.0
# 581         4.0      18.0     1983.0       2.0     29.0   1984.0
# 582         4.0      18.0     1983.0       2.0     29.0   1984.0
# 583         4.0      18.0     1983.0       2.0     29.0   1984.0
# 598         1.0      13.0     1986.0       1.0     29.0   1986.0
# 599         1.0      13.0     1986.0       1.0     29.0   1986.0
# 608         5.0      26.0     1988.0       1.0     26.0   1991.0
# 609         5.0      26.0     1988.0       1.0     26.0   1991.0
# 615         3.0       NaN     1989.0      12.0      4.0   1990.0
# 616         3.0       NaN     1989.0      12.0      4.0   1990.0
# 619         7.0      14.0     1989.0       9.0      NaN   1992.0
# 620         7.0      14.0     1989.0       9.0      NaN   1992.0
# 621         8.0      19.0     1989.0       NaN      NaN      NaN
# 622         8.0      19.0     1989.0       NaN      NaN      NaN
# 632         3.0       1.0     1991.0       3.0     31.0   1991.0
# 633         3.0       1.0     1991.0       3.0     31.0   1991.0
# 636         5.0       2.0     1991.0       1.0      2.0   1992.0
# 637         5.0       2.0     1991.0       1.0      2.0   1992.0
# 691         5.0       NaN     1995.0      11.0      NaN   1995.0
# 692         5.0       NaN     1995.0      11.0      NaN   1995.0
# 693         4.0       5.0     1996.0       8.0     20.0   1996.0
# 694         4.0       5.0     1996.0       8.0     20.0   1996.0
# 697         1.0       1.0     1997.0       1.0     30.0   1997.0
# 698        10.0       8.0     1996.0       5.0     17.0   1997.0
# 699         1.0       1.0     1997.0       5.0     17.0   1997.0
# 700        10.0       8.0     1996.0       5.0     17.0   1997.0
# 701         4.0      28.0     1997.0       5.0     17.0   1997.0
# 748         8.0       7.0     1999.0      10.0      3.0   2003.0
# 749         8.0       7.0     1999.0      10.0      3.0   2003.0
# 750         4.0      23.0     2000.0       6.0     22.0   2001.0
# 751         4.0      23.0     2000.0       6.0     22.0   2001.0
# 754         3.0      21.0     2001.0      10.0      8.0   2003.0
# 755         3.0      21.0     2001.0      10.0      8.0   2003.0
# 756         5.0      21.0     2001.0       9.0      4.0   2001.0
# 757         5.0      21.0     2001.0       9.0      4.0   2001.0
# 769         2.0      26.0     2003.0      12.0     11.0   2006.0
# 770         2.0      26.0     2003.0      12.0     11.0   2006.0
# 775         2.0      20.0     2004.0       9.0      5.0   2006.0
# 776         2.0      20.0     2004.0       9.0      5.0   2006.0
# 777         2.0      20.0     2004.0       9.0      5.0   2006.0
#
#                      Initiator  Outcome  Deaths Side  IsInitiator
# 0                     Chechens        1    5000    A            0
# 1                     Chechens        2    6000    B            0
# 36                   Egyptians        2    8000    A            0
# 37                   Egyptians        1    4000    B            0
# 63                  Mehmet Ali        2    2000    A            0
# 64                  Mehmet Ali        1    1000    B            0
# 78                    Ottomans        1    1600    A            0
# 79                    Ottomans        2    3000    B            0
# 90           Former Pres. Paez        2     NaN    B            0
# 91           Former Pres. Paez        1    1500    A            0
# 100                    Magyars        1   46000    A            0
# 101                    Magyars        1   14500    A            0
# 102                    Magyars        2   20000    B            0
# 105                     Turkey        2     NaN    A            0
# 106                     Turkey        1     NaN    B            0
# 109                   Military        1     600    A            0
# 110                   Military        2    3000    B            0
# 130                    Muslims        1     NaN    A            0
# 131                    Muslims        2     NaN    B            0
# 136             Ottoman Empire        3     NaN    B            0
# 137             Ottoman Empire        3     NaN    A            0
# 142             Gregorio Perez        1     NaN    A            0
# 143             Gregorio Perez        2     NaN    B            0
# 153              Zhang Jizhong        2     NaN    B            0
# 154              Zhang Jizhong        1     NaN    A            0
# 155                Federalists        2     NaN    B            0
# 156                Federalists        1     NaN    A            0
# 242                      Yemen        6   30000    A            0
# 243                      Yemen        6     NaN    B            0
# 258               Yemen & Asir        6    2000    B            0
# 259               Yemen & Asir        6    7000    A            0
# 264                Republicans        2     800    A            0
# 265                Republicans        1     200    B            0
# 279         Kirghiz & Kazables        1     350    A            0
# 280         Kirghiz & Kazables        2    1000    B            0
# 288                 Communists        2    8500    B            0
# 289                 Communists        1    5300    A            0
# 290                        NaN        2     400    B            0
# 291                        NaN        1     950    A            0
# 292                      Poles        4     NaN    B            0
# 293                      Poles        4     NaN    A            0
# 298                Chihli army        2     NaN    A            0
# 299                Chihli army        1     NaN    B            0
# 309        Muslims/Enver Pasha        1    1000    A            0
# 310        Muslims/Enver Pasha        2    2500    B            0
# 330                    Muslims        2     NaN    B            0
# 331                    Muslims        1     NaN    A            0
# 336         Escoban Led Rebels        2    1600    B            0
# 337         Escoban Led Rebels        1     400    A            0
# 355                   Fascists        2  286000    A            0
# 356                   Fascists        1    4000    B            0
# 357                   Fascists        1     300    B            0
# 358                   Fascists        1    2000    B            0
# 359                   Fascists        1  174000    B            0
# 394                       Army        1     NaN    B            0
# 395                       Army        2     NaN    A            0
# 400                   Leftists        1       1    A            0
# 401                   Leftists        2     NaN    B            0
# 402                   Leftists        1     NaN    A            0
# 460                     Karens        7    6800    A            0
# 461                     Karens        7   22400    B            0
# 496                   Pinochet        2     400    A            0
# 497                   Pinochet        1    3000    B            0
# 526                   Fretelin        2     NaN    B            0
# 527                   Fretelin        1    1800    A            0
# 528                Syria & PLO        6    1500    A            0
# 529                Syria & PLO        6     800    B            0
# 530                Syria & PLO        6     800    B            0
# 531                Syria & PLO        6     NaN    A            0
# 544                  Mujahedin        4   21200    B            0
# 545                  Mujahedin        4   11800    A            0
# 546                  Mujahedin        4    2000    A            0
# 551                  Coalition        1     NaN    A            0
# 552                  Coalition        2     NaN    B            0
# 572               Shining Path        2   12000    B            0
# 573               Shining Path        1    4000    A            0
# 578              Kachin Rebels        2    1200    B            0
# 579              Kachin Rebels        1    2800    A            0
# 580                      Druze        2      95    A            0
# 581                      Druze        2     NaN    A            0
# 582                      Druze        2     273    A            0
# 583                      Druze        1     NaN    B            0
# 598                       PDRY        2    4200    A            0
# 599                       PDRY        1    8800    B            0
# 608                        USC        1     NaN    B            0
# 609                        USC        2     NaN    A            0
# 615                       Deby        1     800    B            0
# 616                       Deby        2    3000    A            0
# 619                     P.N.G.        7     NaN    A            0
# 620                     P.N.G.        7     NaN    B            0
# 621          Drug Lords & FARC        5  17,681    B            0
# 622          Drug Lords & FARC        5  10,480    A            0
# 632                    Shiites        1     NaN    A            0
# 633                    Shiites        2     NaN    B            0
# 636                 Yugoslavia        2     NaN    A            0
# 637                 Yugoslavia        1     NaN    B            0
# 691            Krajinian Serba        1     NaN    A            0
# 692            Krajinian Serba        2     NaN    B            0
# 693  National Patriotic Forces        3     NaN    A            0
# 694  National Patriotic Forces        3     NaN    B            0
# 697                Kabila-ADFL        1     NaN    B            0
# 698                Kabila-ADFL        1     NaN    B            0
# 699                Kabila-ADFL        1     NaN    B            0
# 700                Kabila-ADFL        2     NaN    A            0
# 701                Kabila-ADFL        1     NaN    B            0
# 748                    Cechnya        1    5000    A            0
# 749                    Cechnya        2   15000    B            0
# 750               Phillippines        3     NaN    A            0
# 751               Phillippines        3     NaN    B            0
# 754                        FNL        3     150    A            0
# 755                        FNL        3    3000    B            0
# 756                       ALIR        1     NaN    A            0
# 757                       ALIR        2    1800    B            0
# 769                        SLA        6     NaN    A            0
# 770                        SLA        6     NaN    B            0
# 775              US & Pakistan        1    1800    B            0
# 776              US & Pakistan        2     NaN    A            0
# 777              US & Pakistan        2    1200    A            0

# %% [markdown]
# based on manual examination (and googling where entity names in initiator are unclear), I made a list of the df index values where IsInitiator should be 1

# %%
isInitIndex = [1, 37, 63, 78, 90, 102, 105, 110, 131, 137, 143, 153, 155, 243, 258, 265, 280, 288, 293, 299, 310, 330, 336, 
              359, 394, 401, 461, 497, 526, 529, 530, 544, 552, 572, 578, 583, 598, 608, 615, 619, 621, 633, 636, 692, 
              694, 698, 749, 750, 755, 757, 770, 776, 777]

dfIntraWarPar.loc[isInitIndex, 'IsInitiator'] = 1

checkinit2 = dfIntraWarPar.groupby('WarID')['IsInitiator'].sum()
checkinit2.value_counts()
# Out:
# 1    325
# 2      9
# Name: IsInitiator, dtype: int64

# %% [markdown]
# Need to correct errors in date fields. Note: these errors were found when transforming the date feilds into a proper datetime object.

# %%
dfIntraWarPar[(dfIntraWarPar['EndDay'] < 0) | (dfIntraWarPar['EndDay'] > 31)]
# Out:
#      WarID  PolityID                 PolityName  StartMonth  StartDay  \
# 153    585       NaN  Zhang Jizhong's followers        10.0       NaN
# 154    585     710.0                      China        10.0       NaN
# 294    682       NaN           German Freikorps         1.0       6.0
# 295    682       NaN                 Socialists         1.0       6.0
#
#      StartYear  EndMonth   EndDay  EndYear      Initiator  Outcome Deaths  \
# 153     1866.0      10.0 -91866.0      NaN  Zhang Jizhong        2    NaN
# 154     1866.0      10.0 -91866.0      NaN  Zhang Jizhong        1    NaN
# 294     1919.0       5.0   1919.0      NaN     Socialists        1     70
# 295     1919.0       5.0   1919.0      NaN     Socialists        2  2,100
#
#     Side  IsInitiator
# 153    B            1
# 154    A            0
# 294    B            0
# 295    A            1

# %%
dfIntraWarPar[dfIntraWarPar['WarID']==623]
# Out:
#      WarID  PolityID       PolityName  StartMonth  StartDay  StartYear  \
# 211    623       NaN  Tonghak Society         9.0      14.0     1894.0
# 212    623       NaN  Tonghak Society         2.0      29.0     1894.0
# 213    623     730.0            Korea         9.0      14.0     1894.0
# 214    623     730.0            Korea         2.0      29.0     1894.0
# 215    623     740.0            Japan        10.0      24.0     1894.0
#
#      EndMonth  EndDay  EndYear        Initiator  Outcome Deaths Side  \
# 211      11.0    28.0   1894.0  Tonghak Society        2    NaN    B
# 212       5.0     6.0   1894.0  Tonghak Society        2    NaN    B
# 213      11.0    28.0   1894.0  Tonghak Society        1    NaN    A
# 214       5.0     6.0   1894.0  Tonghak Society        1    NaN    A
# 215      11.0    28.0   1894.0  Tonghak Society        1    NaN    A
#
#      IsInitiator
# 211            1
# 212            1
# 213            0
# 214            0
# 215            0

# %%
dfIntraWarPar[dfIntraWarPar['WarID']==585] = dfIntraWarPar.replace({'EndDay': {-91866: np.nan}, 'EndYear': {np.nan: 1866}})
dfIntraWarPar[dfIntraWarPar['WarID']==682] = dfIntraWarPar.replace({'EndDay': {1919: np.nan}, 'EndYear': {np.nan: 1919}})
dfIntraWarPar[dfIntraWarPar['WarID']==623] = dfIntraWarPar.replace({'StartDay': {29: 28}})

# %%
dfIntraWarPar[dfIntraWarPar.index.isin([153, 154, 294, 295, 211, 212, 213, 214, 215])]
# Out:
#      WarID  PolityID                 PolityName  StartMonth  StartDay  \
# 153    585       NaN  Zhang Jizhong's followers        10.0       NaN
# 154    585     710.0                      China        10.0       NaN
# 211    623       NaN            Tonghak Society         9.0      14.0
# 212    623       NaN            Tonghak Society         2.0      28.0
# 213    623     730.0                      Korea         9.0      14.0
# 214    623     730.0                      Korea         2.0      28.0
# 215    623     740.0                      Japan        10.0      24.0
# 294    682       NaN           German Freikorps         1.0       6.0
# 295    682       NaN                 Socialists         1.0       6.0
#
#      StartYear  EndMonth  EndDay  EndYear        Initiator  Outcome Deaths  \
# 153     1866.0      10.0     NaN   1866.0    Zhang Jizhong        2    NaN
# 154     1866.0      10.0     NaN   1866.0    Zhang Jizhong        1    NaN
# 211     1894.0      11.0    28.0   1894.0  Tonghak Society        2    NaN
# 212     1894.0       5.0     6.0   1894.0  Tonghak Society        2    NaN
# 213     1894.0      11.0    28.0   1894.0  Tonghak Society        1    NaN
# 214     1894.0       5.0     6.0   1894.0  Tonghak Society        1    NaN
# 215     1894.0      11.0    28.0   1894.0  Tonghak Society        1    NaN
# 294     1919.0       5.0     NaN   1919.0       Socialists        1     70
# 295     1919.0       5.0     NaN   1919.0       Socialists        2  2,100
#
#     Side  IsInitiator
# 153    B            1
# 154    A            0
# 211    B            1
# 212    B            1
# 213    A            0
# 214    A            0
# 215    A            0
# 294    B            0
# 295    A            1

# %%
dfIntraWarPar['Deaths'] = dfIntraWarPar['Deaths'].str.replace(',', '').astype(float)
dfIntraWarPar = dfIntraWarPar[['WarID', 'PolityID', 'PolityName', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Side', 'IsInitiator', 'Outcome', 'Deaths']]
dfIntraWarPar
# Out:
#      WarID  PolityID                        PolityName  StartYear  StartMonth  \
# 0      500     365.0                            Russia     1818.0         6.0
# 1      500       NaN  Georgians, Dhagestania, Chechens     1818.0         6.0
# 2      501       NaN                             Sidon     1820.0         6.0
# 3      501       NaN                 Damascus & Aleppo     1820.0         6.0
# 4      502       NaN                          Liberals     1820.0         7.0
# ..     ...       ...                               ...        ...         ...
# 790    938     520.0                           Somalia     2006.0         3.0
# 791    940       NaN                              LTTE     2006.0        10.0
# 792    940     780.0                         Sri Lanka     2006.0        10.0
# 793    941       NaN                     Zaidi Muslims     2007.0         1.0
# 794    941     679.0                             Yemen     2007.0         1.0
#
#      StartDay  EndYear  EndMonth  EndDay Side  IsInitiator  Outcome  Deaths
# 0        10.0   1822.0       NaN     NaN    A            0        1  5000.0
# 1        10.0   1822.0       NaN     NaN    B            1        2  6000.0
# 2         NaN   1821.0       7.0    21.0    A            1        2     NaN
# 3         NaN   1821.0       7.0    21.0    B            0        1     NaN
# 4         2.0   1821.0       3.0    23.0    B            1        2     NaN
# ..        ...      ...       ...     ...  ...          ...      ...     ...
# 790       6.0   2008.0       6.0     1.0    A            0        1     NaN
# 791      11.0      NaN       NaN     NaN    B            0        5     NaN
# 792      11.0      NaN       NaN     NaN    A            1        5     NaN
# 793      29.0   2007.0       6.0    16.0    B            1        6  2000.0
# 794      29.0   2007.0       6.0    16.0    A            0        6  1500.0
#
# [795 rows x 13 columns]

# %% [markdown]
# ### Non-State War
#
# - again, all polities belong in a single column
# - all wars have an initiator as A or B, need to change to reflect schema of 1 = is Initiator, 0 = isn't initiator
# - Outcome is set to 1 = side A wins, 2 = side B wins; need to change (side B) to reflect schema of 1 = this side wins, 2 = this side loses

# %%
dfNonStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'WhereFought', 'SideA1', 'SideA2',
#        'SideB1', 'SideB2', 'SideB3', 'SideB4', 'SideB5', 'StartYear',
#        'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Initiator',
#        'TransFrom', 'TransTo', 'Outcome', 'SideADeaths', 'SideBDeaths',
#        'TotalCombatDeaths', 'Version'],
#       dtype='object')

# %%
dfNonWarParA1 = dfNonStateWar[['WarNum', 'SideA1', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 
                               'EndMonth', 'EndDay', 'Initiator', 'Outcome', 'SideADeaths']] \
                             .rename(columns={'SideA1':'PolityName', 'WarNum':'WarID', 'SideADeaths': 'Deaths'})

dfNonWarParA2 = dfNonStateWar[['WarNum', 'SideA2', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 
                               'EndMonth', 'EndDay', 'Initiator', 'Outcome', 'SideADeaths']] \
                             .rename(columns={'SideA2':'PolityName', 'WarNum':'WarID', 'SideADeaths': 'Deaths'})

dfNonWarParB1 = dfNonStateWar[['WarNum', 'SideB1', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 
                               'EndMonth', 'EndDay', 'Initiator', 'Outcome', 'SideBDeaths']] \
                             .rename(columns={'SideB1':'PolityName', 'WarNum':'WarID', 'SideBDeaths': 'Deaths'})

dfNonWarParB2 = dfNonStateWar[['WarNum', 'SideB2', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 
                               'EndMonth', 'EndDay', 'Initiator', 'Outcome', 'SideBDeaths']] \
                             .rename(columns={'SideB2':'PolityName', 'WarNum':'WarID', 'SideBDeaths': 'Deaths'})

dfNonWarParB3 = dfNonStateWar[['WarNum', 'SideB3', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 
                               'EndMonth', 'EndDay', 'Initiator', 'Outcome', 'SideBDeaths']] \
                             .rename(columns={'SideB3':'PolityName', 'WarNum':'WarID', 'SideBDeaths': 'Deaths'})

dfNonWarParB4 = dfNonStateWar[['WarNum', 'SideB4', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 
                               'EndMonth', 'EndDay', 'Initiator', 'Outcome', 'SideBDeaths']] \
                             .rename(columns={'SideB4':'PolityName', 'WarNum':'WarID', 'SideBDeaths': 'Deaths'})

dfNonWarParB5 = dfNonStateWar[['WarNum', 'SideB5', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 
                               'EndMonth', 'EndDay', 'Initiator', 'Outcome', 'SideBDeaths']] \
                             .rename(columns={'SideB5':'PolityName', 'WarNum':'WarID', 'SideBDeaths': 'Deaths'})

# %%
dfNonWarParA = pd.concat([dfNonWarParA1, dfNonWarParA2]) \
               .dropna(subset=['PolityName']).reset_index(drop=True)
dfNonWarParA['Side'] = 'A'
dfNonWarParA['IsInitiator'] = 1
dfNonWarParA.loc[dfNonWarParA['Initiator'] == 'B', 'IsInitiator'] = 0

# %%
dfNonWarParB = pd.concat([dfNonWarParB1, dfNonWarParB2, dfNonWarParB3, dfNonWarParB4, dfNonWarParB5]) \
               .dropna(subset=['PolityName']).reset_index(drop=True)
dfNonWarParB['Side'] = 'B'
dfNonWarParB['IsInitiator'] = 1
dfNonWarParB.loc[dfNonWarParB['Initiator'] == 'A', 'IsInitiator'] = 0

dfNonWarParB = dfNonWarParB.replace({'Outcome': {2: 20, 1: 10}}) \
                           .replace({'Outcome': {20: 1, 10: 2}})

# %%
dfNonWarPar = pd.concat([dfNonWarParA, dfNonWarParB]).sort_values('WarID').reset_index(drop=True)
dfNonWarPar['PolityID'] = np.nan
dfNonWarPar = dfNonWarPar[['WarID', 'PolityID', 'PolityName', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Side', 'IsInitiator', 'Outcome', 'Deaths']]
dfNonWarPar
# Out:
#      WarID  PolityID                PolityName  StartYear  StartMonth  \
# 0     1500       NaN  Te Rauparaha's Ngati Toa       1818         NaN
# 1     1500       NaN                 Ngati Ira       1818         NaN
# 2     1500       NaN                   Waikato       1818         NaN
# 3     1500       NaN                 Ngai Tahu       1818         NaN
# 4     1500       NaN                  Taranaki       1818         NaN
# ..     ...       ...                       ...        ...         ...
# 139   1582       NaN                   Apodeti       1975         8.0
# 140   1582       NaN                  Fretilin       1975         8.0
# 141   1582       NaN                       UDT       1975         8.0
# 142   1594       NaN                     Lendu       1999         6.0
# 143   1594       NaN                     Hemda       1999         6.0
#
#      StartDay  EndYear  EndMonth  EndDay Side  IsInitiator  Outcome  Deaths
# 0         NaN     1824       NaN     NaN    A            1        1  1500.0
# 1         NaN     1824       NaN     NaN    B            0        2  6000.0
# 2         NaN     1824       NaN     NaN    B            0        2  6000.0
# 3         NaN     1824       NaN     NaN    B            0        2  6000.0
# 4         NaN     1824       NaN     NaN    B            0        2  6000.0
# ..        ...      ...       ...     ...  ...          ...      ...     ...
# 139      11.0     1975      10.0    15.0    A            0        4     NaN
# 140      11.0     1975      10.0    15.0    A            0        4     NaN
# 141      11.0     1975      10.0    15.0    B            1        4     NaN
# 142       NaN     2005       3.0     NaN    B            1        6     NaN
# 143       NaN     2005       3.0     NaN    A            0        6     NaN
#
# [144 rows x 13 columns]

# %% [markdown]
# ### Extra-State War
#
# - again, all polities in a single column, no duplicate date columns
# - initiator needs to be fixed for side B (so 1 = this side is initiator)
# - outcome needs to be fixed for side B (so 1 = this side wins, 2 = this side loses)

# %%
dfExtraStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'ccode1', 'SideA', 'ccode2', 'SideB',
#        'StartMonth1', 'StartDay1', 'StartYear1', 'EndMonth1', 'EndDay1',
#        'EndYear1', 'StartMonth2', 'StartDay2', 'StartYear2', 'EndMonth2',
#        'EndDay2 ', 'EndYear2', 'Initiator', 'Interven', 'TransFrom', 'Outcome',
#        'TransTo', 'WhereFought', 'BatDeath', 'NonStateDeaths', 'Version'],
#       dtype='object')

# %%
dfExtraWarPar1A = dfExtraStateWar[['WarNum', 'ccode1', 'SideA', 'StartMonth1', 'StartDay1', 'StartYear1', 
                                   'EndMonth1', 'EndDay1', 'EndYear1', 'Initiator', 'Outcome', 
                                   'BatDeath', 'NonStateDeaths']] \
                                 .rename(columns={'WarNum':'WarID', 'ccode1':'PolityID', 
                                        'SideA':'PolityName', 'StartMonth1':'StartMonth', 
                                        'StartDay1':'StartDay', 'StartYear1':'StartYear', 
                                        'EndMonth1':'EndMonth', 'EndDay1':'EndDay', 
                                        'EndYear1':'EndYear', 'Initiator': 'IsInitiator'})

dfExtraWarPar2A = dfExtraStateWar[['WarNum', 'ccode1', 'SideA', 'StartMonth2', 'StartDay2', 'StartYear2', 
                                   'EndMonth2', 'EndDay2 ', 'EndYear2', 'Initiator', 'Outcome', 
                                   'BatDeath', 'NonStateDeaths']] \
                                 .rename(columns={'WarNum':'WarID', 'ccode1':'PolityID', 
                                        'SideA':'PolityName', 'StartMonth2':'StartMonth', 
                                        'StartDay2':'StartDay', 'StartYear2':'StartYear', 
                                        'EndMonth2':'EndMonth', 'EndDay2 ':'EndDay', 
                                        'EndYear2':'EndYear', 'Initiator': 'IsInitiator'})

dfExtraWarPar1B = dfExtraStateWar[['WarNum', 'ccode2', 'SideB', 'StartMonth1', 'StartDay1', 'StartYear1', 
                                   'EndMonth1', 'EndDay1', 'EndYear1', 'Initiator', 'Outcome', 
                                   'BatDeath', 'NonStateDeaths']] \
                                 .rename(columns={'WarNum':'WarID', 'ccode2':'PolityID', 
                                        'SideB':'PolityName', 'StartMonth1':'StartMonth', 
                                        'StartDay1':'StartDay', 'StartYear1':'StartYear', 
                                        'EndMonth1':'EndMonth', 'EndDay1':'EndDay', 
                                        'EndYear1':'EndYear', 'Initiator': 'IsInitiator'})

dfExtraWarPar2B = dfExtraStateWar[['WarNum', 'ccode2', 'SideB', 'StartMonth2', 'StartDay2', 'StartYear2', 
                                   'EndMonth2', 'EndDay2 ', 'EndYear2', 'Initiator', 'Outcome', 
                                   'BatDeath', 'NonStateDeaths']] \
                                 .rename(columns={'WarNum':'WarID', 'ccode2':'PolityID', 
                                        'SideB':'PolityName', 'StartMonth2':'StartMonth', 
                                        'StartDay2':'StartDay', 'StartYear2':'StartYear', 
                                        'EndMonth2':'EndMonth', 'EndDay2 ':'EndDay', 
                                        'EndYear2':'EndYear', 'Initiator': 'IsInitiator'})

# %%
dfExtraWarParA = pd.concat([dfExtraWarPar1A, dfExtraWarPar2A]) \
                .dropna(subset=['StartDay', 'StartMonth', 'StartYear'], how='all') \
                .reset_index(drop=True)
dfExtraWarParA['Side'] = 'A'

# %%
dfExtraWarParB = pd.concat([dfExtraWarPar1B, dfExtraWarPar2B]) \
                .dropna(subset=['StartDay', 'StartMonth', 'StartYear'], how='all') \
                .reset_index(drop=True) \
                .replace({'IsInitiator': {1: 10, 0: 20}, 'Outcome': {1: 10, 2: 20}}) \
                .replace({'IsInitiator': {10: 0, 20: 1}, 'Outcome': {10: 2, 20: 1}})
dfExtraWarParB['Side'] = 'B'

# %%
dfExtraWarPar = pd.concat([dfExtraWarParA, dfExtraWarParB]) \
                .dropna(subset=['PolityName']).reset_index(drop=True)

dfExtraWarPar['Deaths'] = np.nan
dfExtraWarPar['Deaths'] = np.where(dfExtraWarPar['PolityID'].isna(), dfExtraWarPar['NonStateDeaths'], dfExtraWarPar['BatDeath'])

# %%
dfExtraWarPar = dfExtraWarPar[['WarID', 'PolityID', 'PolityName', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Side', 'IsInitiator', 'Outcome', 'Deaths']]
dfExtraWarPar
# Out:
#      WarID  PolityID                   PolityName  StartYear  StartMonth  \
# 0      300     210.0                  Netherlands     1816.0         8.0
# 1      300     200.0               United Kingdom     1816.0         8.0
# 2      301     640.0               Ottoman Empire     1816.0         9.0
# 3      302     230.0                        Spain     1817.0         1.0
# 4      303     230.0                        Spain     1817.0         4.0
# ..     ...       ...                          ...        ...         ...
# 363    481       NaN           al-Qaeda & Taliban     2001.0        12.0
# 364    482       NaN  al-Qaeda & Iraqi resistence     2003.0         5.0
# 365    334       NaN                         Bali     1849.0         4.0
# 366    379       NaN                  Afghanistan     1879.0         9.0
# 367    454       NaN                 Palestinians     1937.0         8.0
#
#      StartDay  EndYear  EndMonth  EndDay Side  IsInitiator  Outcome   Deaths
# 0        26.0   1816.0       8.0    30.0    A            1        1     13.0
# 1        26.0   1816.0       8.0    30.0    A            1        1    129.0
# 2         NaN   1818.0       9.0    11.0    A            1        1  13500.0
# 3         9.0   1818.0       4.0     5.0    A            0        2   1700.0
# 4        11.0   1819.0       8.0    10.0    A            1        2   3000.0
# ..        ...      ...       ...     ...  ...          ...      ...      ...
# 363      23.0      NaN       NaN     NaN    B            0        5  12000.0
# 364       3.0      NaN       NaN     NaN    B            0        5  20000.0
# 365       2.0   1849.0       6.0    14.0    B            0        6   2000.0
# 366       3.0   1880.0       9.0     2.0    B            0        2  11000.0
# 367       NaN   1939.0       1.0     NaN    B            1        2   2450.0
#
# [368 rows x 13 columns]

# %% [markdown]
# ### Combine all war types
#
# - need to fill in IDs for nonstate actors
# - need to create startdate, startdate_prec, enddate, and enddate_prec columns

# %%
combinedWarPar = [dfInterWarPar, dfIntraWarPar, dfNonWarPar, dfExtraWarPar]
dfWarPar = pd.concat(combinedWarPar, sort=True).sort_values(['WarID', 'Side', 'StartYear']) \
             .drop_duplicates().reset_index(drop=True)

dfWarPar['PolityName'] = dfWarPar['PolityName'].str.strip()

dfWarPar = dfWarPar.merge(dfPolities, on='PolityName', how='left', suffixes=('', '_p'))
dfWarPar['PolityID'] = dfWarPar['PolityID'].fillna(dfWarPar['PolityID_p'])

# %%
dfWarPar = dfWarPar[['WarID', 'PolityID', 'StartYear', 'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Side', 'IsInitiator', 'Outcome', 'Deaths']].drop_duplicates()
dfWarPar
# Out:
#       WarID  PolityID  StartYear  StartMonth  StartDay  EndYear  EndMonth  \
# 0         1     220.0     1823.0         4.0       7.0   1823.0      11.0
# 1         1     230.0     1823.0         4.0       7.0   1823.0      11.0
# 2         4     365.0     1828.0         4.0      26.0   1829.0       9.0
# 3         4     640.0     1828.0         4.0      26.0   1829.0       9.0
# 4         7       2.0     1846.0         4.0      25.0   1847.0       9.0
# ...     ...       ...        ...         ...       ...      ...       ...
# 1666   1582   10042.0     1975.0         8.0      11.0   1975.0      10.0
# 1667   1582   10038.0     1975.0         8.0      11.0   1975.0      10.0
# 1668   1582   10081.0     1975.0         8.0      11.0   1975.0      10.0
# 1669   1594   10039.0     1999.0         6.0       NaN   2005.0       3.0
# 1670   1594   10082.0     1999.0         6.0       NaN   2005.0       3.0
#
#       EndDay Side  IsInitiator  Outcome   Deaths
# 0       13.0    A            1        1    400.0
# 1       13.0    B            0        2    600.0
# 2       14.0    A            1        1  50000.0
# 3       14.0    B            0        2  80000.0
# 4       14.0    A            1        1  13283.0
# ...      ...  ...          ...      ...      ...
# 1666    15.0    A            0        4      NaN
# 1667    15.0    A            0        4      NaN
# 1668    15.0    B            1        4      NaN
# 1669     NaN    A            0        6      NaN
# 1670     NaN    B            1        6      NaN
#
# [1667 rows x 12 columns]

# %%
dfWarPar['StartDate_Prec'] = 'Day'
dfWarPar.loc[dfWarPar['StartDay'].isna(), 'StartDate_Prec'] = 'Month'
dfWarPar.loc[dfWarPar['StartMonth'].isna(), 'StartDate_Prec'] = 'Year'

dfWarPar['EndDate_Prec'] = 'Day'
dfWarPar.loc[dfWarPar['EndDay'].isna(), 'EndDate_Prec'] = 'Month'
dfWarPar.loc[dfWarPar['EndMonth'].isna(), 'EndDate_Prec'] = 'Year'
dfWarPar.loc[dfWarPar['EndYear'].isna(), 'EndDate_Prec'] = 'Ongoing'

dfWarPar['StartDay'] = dfWarPar['StartDay'].fillna(1)
dfWarPar['StartMonth'] = dfWarPar['StartMonth'].fillna(1)
dfWarPar['EndDay'] = np.where(dfWarPar['EndYear'].notna(), dfWarPar['EndDay'].fillna(1), dfWarPar['EndDay'])
dfWarPar['EndMonth'] = np.where(dfWarPar['EndYear'].notna(), dfWarPar['EndMonth'].fillna(1), dfWarPar['EndMonth'])

# %%
dfWarPar = dfWarPar.astype({'StartYear': 'int', 'StartMonth': 'Int64', 'StartDay': 'Int64', 'EndYear': 'Int64', 'EndMonth': 'Int64', 'EndDay': 'Int64', 'PolityID': 'int', 'Deaths': 'Int64'})

dfWarPar['StartDate'] = dfWarPar['StartYear'].astype(str) + '/' + dfWarPar['StartMonth'].astype(str) + '/' + dfWarPar['StartDay'].astype(str)
dfWarPar['EndDate'] = dfWarPar['EndYear'].astype(str) + '/' + dfWarPar['EndMonth'].astype(str) + '/' + dfWarPar['EndDay'].astype(str)
dfWarPar['StartDate'] = pd.to_datetime(dfWarPar['StartDate'], format='%Y/%m/%d')
dfWarPar['EndDate'] = pd.to_datetime(dfWarPar['EndDate'], format='%Y/%m/%d', errors='coerce')

# %%
dfWarPar = dfWarPar[['WarID', 'PolityID', 'StartDate', 'StartDate_Prec', 'EndDate', 'EndDate_Prec', 'Side', 'IsInitiator', 'Outcome', 'Deaths']]
dfWarPar
# Out:
#       WarID  PolityID  StartDate StartDate_Prec    EndDate EndDate_Prec Side  \
# 0         1       220 1823-04-07            Day 1823-11-13          Day    A
# 1         1       230 1823-04-07            Day 1823-11-13          Day    B
# 2         4       365 1828-04-26            Day 1829-09-14          Day    A
# 3         4       640 1828-04-26            Day 1829-09-14          Day    B
# 4         7         2 1846-04-25            Day 1847-09-14          Day    A
# ...     ...       ...        ...            ...        ...          ...  ...
# 1666   1582     10042 1975-08-11            Day 1975-10-15          Day    A
# 1667   1582     10038 1975-08-11            Day 1975-10-15          Day    A
# 1668   1582     10081 1975-08-11            Day 1975-10-15          Day    B
# 1669   1594     10039 1999-06-01          Month 2005-03-01        Month    A
# 1670   1594     10082 1999-06-01          Month 2005-03-01        Month    B
#
#       IsInitiator  Outcome  Deaths
# 0               1        1     400
# 1               0        2     600
# 2               1        1   50000
# 3               0        2   80000
# 4               1        1   13283
# ...           ...      ...     ...
# 1666            0        4     NaN
# 1667            0        4     NaN
# 1668            1        4     NaN
# 1669            0        6     NaN
# 1670            1        6     NaN
#
# [1667 rows x 10 columns]

# %%
dfWarPar.to_csv('../FinalData/war_participants.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Create 'WAR_LOCATIONS' table
#
# Task: transform the following csv files into one table:
#
# - Inter-StateWarData_v4.0.csv (note: already saved as 'dfInterStateWar')
# - Intra-StateWarData_v4.1.csv (note: already saved as 'dfIntraStateWar')
# - Non-StateWarData_v4.0.csv (note: already saved as 'dfNonStateWar')
# - Extra-StateWarData_v4.0.csv (note: already saved as 'dfExtraStateWar')
#
# with the following attributes:
#
# - WarID
# - Region

# %%
dfNonStateWar.columns
# Out:
# Index(['WarNum', 'WarName', 'WarType', 'WhereFought', 'SideA1', 'SideA2',
#        'SideB1', 'SideB2', 'SideB3', 'SideB4', 'SideB5', 'StartYear',
#        'StartMonth', 'StartDay', 'EndYear', 'EndMonth', 'EndDay', 'Initiator',
#        'TransFrom', 'TransTo', 'Outcome', 'SideADeaths', 'SideBDeaths',
#        'TotalCombatDeaths', 'Version'],
#       dtype='object')

# %%
dfInterWarLocs = dfInterStateWar [['WarNum', 'WhereFought']]
dfIntraWarLocs = dfIntraStateWar [['WarNum', 'WhereFought']]
dfExtraWarLocs = dfExtraStateWar [['WarNum', 'WhereFought']]
dfNonWarLocs = dfNonStateWar [['WarNum', 'WhereFought']]

AllWarLocs = [dfInterWarLocs, dfIntraWarLocs, dfExtraWarLocs, dfNonWarLocs]
dfWarLocs = pd.concat(AllWarLocs).drop_duplicates().reset_index(drop=True) \
            .rename(columns={'WarNum':'WarID', 'WhereFought':'Region'})
dfWarLocs
# Out:
#      WarID  Region
# 0        1       2
# 1        4      11
# 2        7       1
# 3       10       2
# 4       13       2
# ..     ...     ...
# 663   1574       4
# 664   1577       6
# 665   1581       4
# 666   1582       7
# 667   1594       4
#
# [668 rows x 2 columns]

# %%
dfWarLocs['WarID'].value_counts()
# Out:
# 139     9
# 106     6
# 100     2
# 440     1
# 407     1
#        ..
# 671     1
# 670     1
# 1552    1
# 658     1
# 1       1
# Name: WarID, Length: 654, dtype: int64

# %% [markdown]
# Note: For all tables except InterState War, the WhereFought variable (Region) indicates where combat occurred. For the InterState War table, WhereFought indicates where combat *involving the state* occured. As a result, 3 (interstate) wars have more than one WhereFought value per war: 139 (WWII), 106 (WWI), and 100 (First Balkan War). For the purposes of this table, Region will track where combat occurred - thus losing some granularity for states involved in these three interstate wars.

# %%
region_map_values = {1: 'W. Hemisphere', 2: 'Europe', 4: 'Africa', 6: 'Middle East', 7: 'Asia', 9: 'Oceania', 
                     11: 'Europe, Middle East', 12: 'Europe, Asia', 13: 'W. Hemisphere, Asia', 
                     14: 'Europe, Africa, Middle East', 15: 'Europe, Africa, Middle East, Asia', 
                     16: 'Africa, Middle East, Asia, Oceania', 17: 'Asia, Oceania', 18: 'Africa, Middle East', 
                     19: 'Europe, Africa, Middle East, Asia, Oceania'}

dfWarLocs['Region'] = dfWarLocs['Region'].replace(region_map_values) \
                                         .str.split(', ')
dfWarLocs = dfWarLocs.explode('Region') \
                     .drop_duplicates() \
                     .reset_index(drop=True)
dfWarLocs
# Out:
#      WarID         Region
# 0        1         Europe
# 1        4         Europe
# 2        4    Middle East
# 3        7  W. Hemisphere
# 4       10         Europe
# ..     ...            ...
# 662   1574         Africa
# 663   1577    Middle East
# 664   1581         Africa
# 665   1582           Asia
# 666   1594         Africa
#
# [667 rows x 2 columns]

# %%
dfWarLocs['WarID'].value_counts().head(10)
# Out:
# 139    5
# 106    4
# 100    2
# 79     2
# 207    2
# 115    2
# 61     2
# 4      2
# 404    1
# 412    1
# Name: WarID, dtype: int64

# %%
dfWarLocs.to_csv('../FinalData/war_locations.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Create 'WAR_TRANSITIONS' table
#
# Task: transform the following csv files into one table:
#
# - Inter-StateWarData_v4.0.csv (note: already saved as 'dfInterStateWar')
# - Intra-StateWarData_v4.1.csv (note: already saved as 'dfIntraStateWar')
# - Non-StateWarData_v4.0.csv (note: already saved as 'dfNonStateWar')
# - Extra-StateWarData_v4.0.csv (note: already saved as 'dfExtraStateWar')
#
# with the following attributes:
#
# - FromWar
# - ToWar

# %%
dfInterWarTrans = dfInterStateWar[['WarNum', 'TransTo']]
dfIntraWarTrans = dfIntraStateWar[['WarNum', 'TransTo']]
dfNonWarTrans = dfNonStateWar[['WarNum', 'TransTo']]
dfExtraWarTrans = dfExtraStateWar[['WarNum', 'TransTo']]

allWarTrans = [dfInterWarTrans, dfIntraWarTrans, dfNonWarTrans, dfExtraWarTrans]
dfWarTrans = pd.concat(allWarTrans).dropna().drop_duplicates().sort_values('WarNum').reset_index(drop=True)
dfWarTrans = dfWarTrans.rename(columns={'WarNum':'FromWar', 'TransTo':'ToWar'}).astype({'ToWar':int})
dfWarTrans
# Out:
#     FromWar  ToWar
# 0        40    587
# 1       176    785
# 2       186    804
# 3       187    808
# 4       189    475
# 5       215    877
# 6       225    481
# 7       227    482
# 8       327     19
# 9       352     37
# 10      373     61
# 11      385     67
# 12      404     79
# 13      410     79
# 14      469   1581
# 15      472    806
# 16      475    857
# 17      476    851
# 18      503      1
# 19      506      4
# 20      545    553
# 21      551     10
# 22      601    373
# 23      631     76
# 24      650    100
# 25      681    109
# 26      748    163
# 27      756    170
# 28      772    776
# 29      782    178
# 30      805    187
# 31      812    476
# 32      851    225
# 33      872    216
# 34      900    221
# 35     1527    538
# 36     1534    567
# 37     1537    570
# 38     1541    571
# 39     1571    461
# 40     1572    148
# 41     1581    186
# 42     1582    472

# %%
dfWarTrans.to_csv('../FinalData/war_transitions.csv', encoding='utf-8', index=False)
